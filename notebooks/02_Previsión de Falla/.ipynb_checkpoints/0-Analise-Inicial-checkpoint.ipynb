# %% [markdown]
# ## Descripción
# - Los galpones de Full de mercado libre cuentan con una flota de dispositivos que transmiten
# diariamente telemetría agregada en varios atributos.
# - Las técnicas de mantenimiento predictivo están diseñadas para ayudar a determinar la
# condición del equipo de mantenimiento en servicio para predecir cuándo se debe realizar el
# mantenimiento. Este enfoque promete ahorros de costos sobre el mantenimiento preventivo
# de rutina o basado en el tiempo porque las tareas se realizan solo cuando están justificadas.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_devices = pd.read_csv('../../../data/00_raw/full_devices.csv', encoding="latin1")

# %% [markdown]
# <b> Empezaremos con los basicos, nulos y despues descriciones generales del dataframe

# %%
df_devices.sample(3)
# Out:
#              date    device  failure  attribute1  attribute2  attribute3  \
# 20340  2015-01-25  S1F136KJ        0    58526208           0           0
# 24673  2015-01-31  W1F0KRWP        0   164579368           0           0
# 96006  2015-06-24  W1F1DQJD        0    85377992           0           0
#
#        attribute4  attribute5  attribute6  attribute7  attribute8  attribute9
# 20340           6          11      209351           0           0           0
# 24673           0           7      316706           0           0          10
# 96006           0           4           9           0           0           0

# %%
df_devices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124494 entries, 0 to 124493
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        124494 non-null  object
#  1   device      124494 non-null  object
#  2   failure     124494 non-null  int64
#  3   attribute1  124494 non-null  int64
#  4   attribute2  124494 non-null  int64
#  5   attribute3  124494 non-null  int64
#  6   attribute4  124494 non-null  int64
#  7   attribute5  124494 non-null  int64
#  8   attribute6  124494 non-null  int64
#  9   attribute7  124494 non-null  int64
#  10  attribute8  124494 non-null  int64
#  11  attribute9  124494 non-null  int64
# dtypes: int64(10), object(2)
# memory usage: 11.4+ MB

# %% [markdown]
# <b> O que tenemos acá: </b>
# - No tenemos nulos
# - La grande mayoria de nuestros datos son int, tenemos solo 2 strings <br>
# Vamos entender un poquito del dataset, distribuciones por supuesto tambien si tenemos un desbalanceamiento en los failures

# %%
df_devices.describe(include='all')
# Out:
#               date    device        failure    attribute1     attribute2  \
# count       124494    124494  124494.000000  1.244940e+05  124494.000000
# unique         304      1169            NaN           NaN            NaN
# top     2015-01-01  S1F0E9EP            NaN           NaN            NaN
# freq          1163       304            NaN           NaN            NaN
# mean           NaN       NaN       0.000851  1.223881e+08     159.484762
# std            NaN       NaN       0.029167  7.045933e+07    2179.657730
# min            NaN       NaN       0.000000  0.000000e+00       0.000000
# 25%            NaN       NaN       0.000000  6.128476e+07       0.000000
# 50%            NaN       NaN       0.000000  1.227974e+08       0.000000
# 75%            NaN       NaN       0.000000  1.833096e+08       0.000000
# max            NaN       NaN       1.000000  2.441405e+08   64968.000000
#
#            attribute3     attribute4     attribute5     attribute6  \
# count   124494.000000  124494.000000  124494.000000  124494.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         9.940455       1.741120      14.222669  260172.657726
# std        185.747321      22.908507      15.943028   99151.078547
# min          0.000000       0.000000       1.000000       8.000000
# 25%          0.000000       0.000000       8.000000  221452.000000
# 50%          0.000000       0.000000      10.000000  249799.500000
# 75%          0.000000       0.000000      12.000000  310266.000000
# max      24929.000000    1666.000000      98.000000  689161.000000
#
#            attribute7     attribute8     attribute9
# count   124494.000000  124494.000000  124494.000000
# unique            NaN            NaN            NaN
# top               NaN            NaN            NaN
# freq              NaN            NaN            NaN
# mean         0.292528       0.292528      12.451524
# std          7.436924       7.436924     191.425623
# min          0.000000       0.000000       0.000000
# 25%          0.000000       0.000000       0.000000
# 50%          0.000000       0.000000       0.000000
# 75%          0.000000       0.000000       0.000000
# max        832.000000     832.000000   18701.000000

# %% [markdown]
# <b> Ya luego miramos que existe un desbalanceamiento en los failures listo que solo despues de nuestro Q3 tenemos dados con fallas </b>
# - Necesitamos entender un poco mejor como está eso, tenemos 1169 devices, es posible que todos tengan fallas o tienen devices que no contienen fallas?

# %%
df_devices.groupby(['device', 
                    'failure']).agg({'failure':'count'})
# Out:
#                   failure
# device   failure
# S1F01085 0              6
# S1F013BB 0              6
# S1F0166B 0              6
# S1F01E6Y 0             48
# S1F01JE0 0              6
# ...                   ...
# Z1F1VQFY 0            124
#          1              1
# Z1F26YZB 0             84
# Z1F282ZV 0             84
# Z1F2PBHX 0             83
#
# [1275 rows x 1 columns]

# %% [markdown]
# <b> Pues existen muchos devices que no contienen fallas </b>
# - Cuantos devices contienen fallas?

# %%
df_devices.loc[df_devices['failure'] == 1,'device'].nunique()
# Out:
# 106

# %%
df_devices.loc[df_devices['failure'] == 1].shape[0] / len(df_devices)
# Out:
# 0.000851446656063746

# %% [markdown]
# <b> De los 1169 solo 106 tuvieran fallas </b>
# - Ese es el numero de lineas que tuvieran fallas tambien
# - ~0.001% de nuestro dataset tiene fallas.

# %% [markdown]
# <b> Cual es nuestro range de datas para los datos? </b>

# %%
df_devices['date'].min()
# Out:
# '2015-01-01'

# %%
df_devices['date'].max()
# Out:
# '2015-11-02'

# %% [markdown]
# <B> Tenemos datos de 11 meses </b>
# - Eso nos abre oportunidad de crear series temporales para hacer una analise de anomalias arriba de los atributos -- Pero tenemos muchas variables y muchos devices, talvez alguna cosa un poquito mas simples como:
#     - Una arbore de decisiones para classificacion
#     - Una regression logistica para classificacion
# - Por ahora son las ideas que tengo

# %% [markdown]
# ### Vamos ahora para correlacion entre as variables para entender se tenemos que tratar de multicolinearidade

# %%
# Compute correlation matrix
corr = df_devices.corr(numeric_only=True)

# %%
# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Define a Mercado Livre-inspired palette: deep blue to yellow
cmap = sns.diverging_palette(230, 45, s=99, l=55, as_cmap=True)  

# Create heatmap
sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap=cmap,
    center=0,
    linewidths=0.5,
    cbar_kws={"shrink": 0.8, "label": "Correlation Coefficient"}
)

# Titles and styling
plt.title("Mercado Envios – Numeric Variables Correlation", fontsize=16, fontweight="bold", pad=15)
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.yticks(rotation=0, fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# <b> Analise de la correlacion </b>
# - Failure tiene correlacion 0 con algunas variables, pero en Machine Learning puede existir correlacion entre variables y por eso no pondremos descartalas
# - De principio attribute 7 y 8 son la misma variable y ya pondremos deletar
# - Attribute 3 y 9 tienen una alta correlacion y ningun tiene correlacion con failure, vamos dejarlos por ahora pero vamos entender un poquito mejor

# %%
# Scatter plot: attribute_3 vs attribute_9
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

sns.scatterplot(
    data=df_devices,
    x="attribute3",
    y="attribute9",
    color="#002F6C",
    edgecolor="white",
    s=60,                  # Point size
    alpha=0.7              # Transparency for overlap
)

# Titles and labels
plt.title("Attribute 3 vs Attribute 9", fontsize=16, fontweight="bold", pad=15)
plt.xlabel("Attribute 3", fontsize=12)
plt.ylabel("Attribute 9", fontsize=12)

# Optional regression line
sns.regplot(
    data=df_devices,
    x="attribute3",
    y="attribute9",
    scatter=False,
    color="#FFD100",       # Mercado yellow
    line_kws={"linewidth": 2}
)

plt.tight_layout()
plt.show()

# %%
# Scatter plot: attribute_3 vs attribute_9
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

sns.scatterplot(
    data=df_devices.loc[df_devices['attribute9'] < 2500],
    x="attribute3",
    y="attribute9",
    color="#002F6C",
    edgecolor="white",
    s=60,                  # Point size
    alpha=0.7              # Transparency for overlap
)

# Titles and labels
plt.title("Attribute 3 vs Attribute 9", fontsize=16, fontweight="bold", pad=15)
plt.xlabel("Attribute 3", fontsize=12)
plt.ylabel("Attribute 9", fontsize=12)

# Optional regression line
sns.regplot(
    data=df_devices.loc[df_devices['attribute9'] < 2500],
    x="attribute3",
    y="attribute9",
    scatter=False,
    color="#FFD100",       # Mercado yellow
    line_kws={"linewidth": 2}
)

plt.tight_layout()
plt.show()

# %%
df_devices.loc[df_devices['attribute3']> 20000]
# Out:
#             date    device  failure  attribute1  attribute2  attribute3  \
# 27    2015-01-01  S1F04KSC        0   105234552         392       24929
# 1190  2015-01-02  S1F04KSC        0   209131472         392       24929
# 2353  2015-01-03  S1F04KSC        0   189393960         392       24929
# 3516  2015-01-04  S1F04KSC        0   243217648         392       24929
#
#       attribute4  attribute5  attribute6  attribute7  attribute8  attribute9
# 27           529           3      339205           0           0       10137
# 1190         529           3      339205           0           0       10137
# 2353         529           3      339205           0           0       10137
# 3516         529           3      339302           0           0       10137

# %%
df_devices.loc[df_devices['attribute9']> 17000]
# Out:
#             date    device  failure  attribute1  attribute2  attribute3  \
# 1145  2015-01-01  Z1F1AGW1        0   171637640           0           0
# 2308  2015-01-02  Z1F1AGW1        0   191913592           0           0
# 3471  2015-01-03  Z1F1AGW1        0   215848672           0           0
# 4633  2015-01-04  Z1F1AGW1        0   238702720           0           0
# 5794  2015-01-05  Z1F1AGW1        0    19586528           0           0
#
#       attribute4  attribute5  attribute6  attribute7  attribute8  attribute9
# 1145           0           7      279827           0           0       18701
# 2308           0           7      281136           0           0       18701
# 3471           0           7      282454           0           0       18701
# 4633           0           7      283818           0           0       18701
# 5794           0           7      285117           0           0       18701

# %% [markdown]
# <b> Es interesante que muchas vezes lo device esta siempre reportando lo mismo, todos los dias </b>
# - Por más que exista una correlacion no es tán visible y si existen puntos que son muy distintos en comportamiento
