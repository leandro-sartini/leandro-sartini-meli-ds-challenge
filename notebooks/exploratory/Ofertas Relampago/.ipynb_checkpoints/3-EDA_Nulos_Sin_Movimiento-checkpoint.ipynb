# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Vamos empezar con lo entendimiento dos sin movimiento
# - Las columnas SOLD_AMOUNT y SOLD_QUANTITY contienen únicamente valores nulos en este subconjunto. Estos nulos no representan datos faltantes por error, sino que son nulos estructurales, lo que significa que estas ofertas no tuvieron ventas. Esto se confirma porque, en todos los casos, REMAINING_STOCK_AFTER_END es igual a INVOLVED_STOCK, indicando que no hubo movimiento de inventario.
# - Este comportamiento se analizará considerando dimensiones como el tiempo de publicación, la duración de la oferta, la categoría del producto (VERTICAL), el dominio agregado (DOM_DOMAIN_AGG1), el tipo de envío (SHIPPING_PAYMENT_TYPE) y el origen (ORIGIN). El objetivo es identificar patrones y posibles factores asociados a la falta de ventas.

# %%
df_no_mov = pd.read_parquet('../../../data/01_processed/ofertas_relampago_sin_ventas_stock_no_movimentado.parquet')

# %%
df_no_mov
# Out:
#       OFFER_START_DATE           OFFER_START_DTTM          OFFER_FINISH_DTTM  \
# 0           2021-06-22  2021-06-22 13:00:00+00:00  2021-06-22 19:00:02+00:00
# 1           2021-06-22  2021-06-22 18:00:00+00:00  2021-06-23 01:00:12+00:00
# 2           2021-06-22  2021-06-22 13:00:00+00:00  2021-06-22 19:00:00+00:00
# 3           2021-06-22  2021-06-22 19:00:00+00:00  2021-06-23 01:00:04+00:00
# 4           2021-06-22  2021-06-22 15:00:00+00:00  2021-06-22 23:00:00+00:00
# ...                ...                        ...                        ...
# 23574       2021-06-19  2021-06-19 15:00:00+00:00  2021-06-19 23:00:00+00:00
# 23575       2021-06-19  2021-06-19 15:00:00+00:00  2021-06-19 23:00:01+00:00
# 23576       2021-06-19  2021-06-19 13:00:00+00:00  2021-06-19 21:00:00+00:00
# 23577       2021-06-19  2021-06-19 13:00:00+00:00  2021-06-19 19:00:01+00:00
# 23578       2021-06-19  2021-06-19 13:00:00+00:00  2021-06-19 19:00:00+00:00
#
#            OFFER_TYPE  INVOLVED_STOCK  REMAINING_STOCK_AFTER_END  SOLD_AMOUNT  \
# 0      lightning_deal               5                          5          NaN
# 1      lightning_deal              23                         23          NaN
# 2      lightning_deal              10                         10          NaN
# 3      lightning_deal              15                         15          NaN
# 4      lightning_deal               6                          6          NaN
# ...               ...             ...                        ...          ...
# 23574  lightning_deal              10                         10          NaN
# 23575  lightning_deal              10                         10          NaN
# 23576  lightning_deal              30                         30          NaN
# 23577  lightning_deal               5                          5          NaN
# 23578  lightning_deal              15                         15          NaN
#
#        SOLD_QUANTITY ORIGIN SHIPPING_PAYMENT_TYPE DOM_DOMAIN_AGG1  \
# 0                NaN   None         free_shipping    PET PRODUCTS
# 1                NaN      A         free_shipping       COMPUTERS
# 2                NaN   None         free_shipping       COMPUTERS
# 3                NaN   None                  none     ELECTRONICS
# 4                NaN      A         free_shipping       PETS FOOD
# ...              ...    ...                   ...             ...
# 23574            NaN      A         free_shipping          MOBILE
# 23575            NaN      A         free_shipping          MOBILE
# 23576            NaN      A                  none      HOME&DECOR
# 23577            NaN   None         free_shipping      HOME&DECOR
# 23578            NaN   None         free_shipping      HOME&DECOR
#
#               VERTICAL                    DOMAIN_ID
# 0               OTHERS  MLM-ANIMAL_AND_PET_PRODUCTS
# 1                   CE               MLM-HEADPHONES
# 2                   CE               MLM-HEADPHONES
# 3                   CE      MLM-ELECTRONIC_PRODUCTS
# 4                  CPG      MLM-CATS_AND_DOGS_FOODS
# ...                ...                          ...
# 23574               CE               MLM-TELEPHONES
# 23575               CE               MLM-TELEPHONES
# 23576  HOME & INDUSTRY                  MLM-MIRRORS
# 23577  HOME & INDUSTRY     MLM-DECORATIVE_PAINTINGS
# 23578  HOME & INDUSTRY               MLM-BED_SHEETS
#
# [23579 rows x 13 columns]

# %% [markdown]
# ## Cuasi metad das ofertas fueran sin movimientos, recorda que tuviemos ~45k de lineas y con ese tenemos 23k
# - Vamos investigar las principales verticales, tipos de shipping y dominio

# %%
df_no_mov.describe(include= 'all')
# Out:
#        OFFER_START_DATE           OFFER_START_DTTM          OFFER_FINISH_DTTM  \
# count             23579                      23579                      23579
# unique               61                        715                       2844
# top          2021-07-09  2021-07-30 07:00:00+00:00  2021-07-08 19:00:01+00:00
# freq                698                        189                         47
# mean                NaN                        NaN                        NaN
# std                 NaN                        NaN                        NaN
# min                 NaN                        NaN                        NaN
# 25%                 NaN                        NaN                        NaN
# 50%                 NaN                        NaN                        NaN
# 75%                 NaN                        NaN                        NaN
# max                 NaN                        NaN                        NaN
#
#             OFFER_TYPE  INVOLVED_STOCK  REMAINING_STOCK_AFTER_END  \
# count            23579    23579.000000               23579.000000
# unique               1             NaN                        NaN
# top     lightning_deal             NaN                        NaN
# freq             23579             NaN                        NaN
# mean               NaN       15.675898                  15.675898
# std                NaN       45.018245                  45.018245
# min                NaN        1.000000                   1.000000
# 25%                NaN        5.000000                   5.000000
# 50%                NaN       10.000000                  10.000000
# 75%                NaN       15.000000                  15.000000
# max                NaN     2000.000000                2000.000000
#
#         SOLD_AMOUNT  SOLD_QUANTITY ORIGIN SHIPPING_PAYMENT_TYPE  \
# count           0.0            0.0   5873                 23579
# unique          NaN            NaN      1                     2
# top             NaN            NaN      A         free_shipping
# freq            NaN            NaN   5873                 14455
# mean            NaN            NaN    NaN                   NaN
# std             NaN            NaN    NaN                   NaN
# min             NaN            NaN    NaN                   NaN
# 25%             NaN            NaN    NaN                   NaN
# 50%             NaN            NaN    NaN                   NaN
# 75%             NaN            NaN    NaN                   NaN
# max             NaN            NaN    NaN                   NaN
#
#        DOM_DOMAIN_AGG1      VERTICAL         DOMAIN_ID
# count            23579         23579             23579
# unique              36             9              1031
# top         HOME&DECOR  APP & SPORTS  MLM-WRISTWATCHES
# freq              3317          6589               256
# mean               NaN           NaN               NaN
# std                NaN           NaN               NaN
# min                NaN           NaN               NaN
# 25%                NaN           NaN               NaN
# 50%                NaN           NaN               NaN
# 75%                NaN           NaN               NaN
# max                NaN           NaN               NaN

# %% [markdown]
# <b> De las descriciones que tenemos por supuesto no sea un problema de shipping pues más de la metad de esos son free_shipping. </b>
# - Vamos investigar un poquito más las categorias

# %%
df_no_mov["DURATION_HOURS"].mean()
# Out:
# np.float64(5.448181573999462)

# %% [markdown]
# <b> Home & Decor sola gaña lo top, pero APP tiene muchas categorias distribuidas y por eso miramos que está rankeada como 1 de las verticales </b>

# %%
# Convertir fechas
df_no_mov["OFFER_START_DTTM"] = pd.to_datetime(df_no_mov["OFFER_START_DTTM"])
df_no_mov["OFFER_FINISH_DTTM"] = pd.to_datetime(df_no_mov["OFFER_FINISH_DTTM"])

# Duración de la oferta en horas
df_no_mov["DURATION_HOURS"] = (df_no_mov["OFFER_FINISH_DTTM"] - df_no_mov["OFFER_START_DTTM"]).dt.total_seconds() / 3600

# %%
# Histograma de duración
plt.figure(figsize=(8,5))
plt.hist(df_no_mov["DURATION_HOURS"], bins=30, edgecolor="black")
plt.title("Distribución de duración de ofertas sin ventas")
plt.xlabel("Duración (horas)")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### Por lo histograma tenemos que:
# - La distribuicion esta concentrada en la izquieda eso por si ya nos demonstra que tenemos outliers, probable es lo de APP que ya miramos en otra etapa
# - Bien concentrada entre 0 y 10 horas o que pondrian ser testes pero aun esta en la media de 6 horas

# %%
# Top categorías (VERTICAL)
plt.figure(figsize=(10,5))
df_no_mov["VERTICAL"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 categorías (VERTICAL) con ofertas sin ventas")
plt.ylabel("Cantidad de ofertas")
plt.xticks(rotation=45)
plt.show()

# %%
# Top dominios agregados (DOM_DOMAIN_AGG1)
plt.figure(figsize=(10,5))
df_no_mov["DOM_DOMAIN_AGG1"].value_counts().head(10).plot(kind="bar", color="orange")
plt.title("Top 10 dominios agregados con ofertas sin ventas")
plt.ylabel("Cantidad de ofertas")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Por supuesto miramo que las top 5 domain son de APP y HOME & Industry
# - La mayor categoria es Home & Decor
# - La segunda, tercera y cuarta son de APP y sports que es donde están las mayores ofertas que no tiene ninguna venta

# %%
# Efecto del tipo de envío
plt.figure(figsize=(8,5))
df_no_mov["SHIPPING_PAYMENT_TYPE"].value_counts().plot(kind="bar", color="green")
plt.title("Tipo de envío en ofertas sin ventas")
plt.ylabel("Cantidad de ofertas")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Tenemos más de la metad en free_shipping entonces no pondremos considerar ese uno de los factores tambien.

# %%
# Cross-tab VERTICAL x Tipo de envío
tabla_cross = pd.crosstab(df_no_mov["VERTICAL"], df_no_mov["SHIPPING_PAYMENT_TYPE"])
tabla_cross.plot(kind="bar", stacked=True, figsize=(12,6))
plt.title("Combinación VERTICAL x Tipo de envío (ofertas sin ventas)")
plt.ylabel("Cantidad de ofertas")
plt.xticks(rotation=90)
plt.show()
