# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_offer = pd.read_csv('../../../data/01_processed/ofertas_relampago.parquet')

# %%
df_offer.sample(3)
# Out:
#       OFFER_START_DATE           OFFER_START_DTTM          OFFER_FINISH_DTTM  \
# 31535       2021-07-25  2021-07-25 13:00:00+00:00  2021-07-25 13:00:01+00:00
# 47527       2021-07-06  2021-07-06 07:00:00+00:00  2021-07-06 13:00:02+00:00
# 2182        2021-06-02  2021-06-02 13:00:00+00:00  2021-06-02 13:00:13+00:00
#
#        INVOLVED_STOCK  REMAINING_STOCK_AFTER_END  SOLD_AMOUNT  SOLD_QUANTITY  \
# 31535               5                          5          NaN            NaN
# 47527               5                          5          NaN            NaN
# 2182               15                         15          NaN            NaN
#
#       ORIGIN SHIPPING_PAYMENT_TYPE DOM_DOMAIN_AGG1         VERTICAL  \
# 31535  Otros                  none      STATIONARY  HOME & INDUSTRY
# 47527  Otros                  none     ELECTRONICS               CE
# 2182   Otros         free_shipping       PETS FOOD              CPG
#
# ...
